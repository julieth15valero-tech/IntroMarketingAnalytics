# %% [markdown]
# # Taller: Análisis de Instagram con Apify API + Gemini
#
# Fecha de generación: 2025-05-21

# %% [markdown]
# **Objetivos**
#
# 1. Obtener datos públicos de Instagram usando el actor **`apify/instagram-api-scraper`**.
# 2. Limpiar y pre‑procesar captions e información de posts (descriptiva de los captions).
# 3. Clasificar sentimiento de captions con la API de Google Generative AI (Gemini).
# 4. Extraer temas dominantes con LDA y nombrarlos con Gemini. Crear Prompt
# 6. Diseñar una micro‑campaña basada en los insights descubiertos.

# %%
import pandas as pd
import requests
import google.generativeai as palm

# %%
# 🔑 Introduce tu token de Apify y de Google Generative AI (Gemini)
import os

# %%
# !wget https://github.com/javierherrera1996/IntroMarketingAnalytics/raw/refs/heads/main/TercerCorte/instagram_disney.csv
# Out:
# --2025-11-27 16:29:05--  https://github.com/javierherrera1996/IntroMarketingAnalytics/raw/refs/heads/main/TercerCorte/instagram_disney.csv
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/javierherrera1996/IntroMarketingAnalytics/refs/heads/main/TercerCorte/instagram_disney.csv [following]
# --2025-11-27 16:29:06--  https://raw.githubusercontent.com/javierherrera1996/IntroMarketingAnalytics/refs/heads/main/TercerCorte/instagram_disney.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10377469 (9.9M) [text/plain]
# Saving to: ‘instagram_disney.csv’
#
# instagram_disney.cs 100%[===================>]   9.90M  --.-KB/s    in 0.1s
#
# 2025-11-27 16:29:06 (86.2 MB/s) - ‘instagram_disney.csv’ saved [10377469/10377469]

# %%
import pandas as pd

df = pd.read_csv("instagram_disney.csv")

# %%
df
# Out:
#                                  inputUrl                   id   username  \
# 0    https://www.instagram.com/disneylat/  3626608212947059675  disneylat
# 1    https://www.instagram.com/disneylat/  3636752063146304692  disneylat
# 2    https://www.instagram.com/disneylat/  3629059382491345626  disneylat
# 3    https://www.instagram.com/disneylat/  3624961017727223603  disneylat
# 4    https://www.instagram.com/disneylat/  3634637246638652679  disneylat
# ..                                    ...                  ...        ...
# 195  https://www.instagram.com/disneylat/  3378657362149709028  disneylat
# 196  https://www.instagram.com/disneylat/  3333366985910424893  disneylat
# 197  https://www.instagram.com/disneylat/  3331639585011555501  disneylat
# 198  https://www.instagram.com/disneylat/  3329464423368675903  disneylat
# 199  https://www.instagram.com/disneylat/  3324475380265171909  disneylat
#
#                                           url fullName  \
# 0    https://www.instagram.com/p/DJUTPSAOUPb/   Disney
# 1    https://www.instagram.com/p/DJ4VrusASS0/   Disney
# 2    https://www.instagram.com/p/DJdAkfiMfLa/   Disney
# 3    https://www.instagram.com/p/DJOctb6RQcz/   Disney
# 4    https://www.instagram.com/p/DJw01GVTP0H/   Disney
# ..                                        ...      ...
# 195  https://www.instagram.com/p/C7jZvhQsRTk/   Disney
# 196  https://www.instagram.com/p/C5Cf5zdNJU9/   Disney
# 197  https://www.instagram.com/p/C48XI0APlyt/   Disney
# 198  https://www.instagram.com/p/C40okC3MNI_/   Disney
# 199  https://www.instagram.com/p/C4i6L6ZPLvF/   Disney
#
#                                            biography externalUrls  \
# 0    La cuenta oficial de Disney para Latinoamérica.           []
# 1    La cuenta oficial de Disney para Latinoamérica.           []
# 2    La cuenta oficial de Disney para Latinoamérica.           []
# 3    La cuenta oficial de Disney para Latinoamérica.           []
# 4    La cuenta oficial de Disney para Latinoamérica.           []
# ..                                               ...          ...
# 195  La cuenta oficial de Disney para Latinoamérica.           []
# 196  La cuenta oficial de Disney para Latinoamérica.           []
# 197  La cuenta oficial de Disney para Latinoamérica.           []
# 198  La cuenta oficial de Disney para Latinoamérica.           []
# 199  La cuenta oficial de Disney para Latinoamérica.           []
#
#      followersCount  followsCount  hasChannel  ...  videoDuration  \
# 0            569613            36       False  ...            NaN
# 1            569613            36       False  ...            NaN
# 2            569613            36       False  ...         59.179
# 3            569613            36       False  ...            NaN
# 4            569613            36       False  ...            NaN
# ..              ...           ...         ...  ...            ...
# 195          569613            36       False  ...        115.115
# 196          569613            36       False  ...            NaN
# 197          569613            36       False  ...            NaN
# 198          569613            36       False  ...            NaN
# 199          569613            36       False  ...            NaN
#
#      musicInfo.artist_name  musicInfo.song_name  \
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                 sacqspot       Original audio
# 3                      NaN                  NaN
# 4                      NaN                  NaN
# ..                     ...                  ...
# 195       disneyprincesala       Original audio
# 196                    NaN                  NaN
# 197                    NaN                  NaN
# 198                    NaN                  NaN
# 199                    NaN                  NaN
#
#      musicInfo.uses_original_audio  musicInfo.should_mute_audio  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                             True                        False
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ..                             ...                          ...
# 195                           True                        False
# 196                            NaN                          NaN
# 197                            NaN                          NaN
# 198                            NaN                          NaN
# 199                            NaN                          NaN
#
#      musicInfo.should_mute_audio_reason musicInfo.audio_id  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN       6.053466e+14
# 3                                   NaN                NaN
# 4                                   NaN                NaN
# ..                                  ...                ...
# 195                                 NaN       9.840821e+14
# 196                                 NaN                NaN
# 197                                 NaN                NaN
# 198                                 NaN                NaN
# 199                                 NaN                NaN
#
#                                            taggedUsers  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195  [{'full_name': 'Disney', 'id': '2957422264', '...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                      coauthorProducers isPinned
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# ..                                                 ...      ...
# 195  [{'id': '2957422264', 'is_verified': True, 'pr...      NaN
# 196                                                NaN      NaN
# 197                                                NaN      NaN
# 198                                                NaN      NaN
# 199                                                NaN      NaN
#
# [200 rows x 58 columns]

# %% [markdown]
# ### 🔍 Preguntas – Sección 1 (Exploración)
# Mire las columnas de su dataset y responda
# 1. ¿Cuántos posts hay en total?
# 2. ¿Qué tipos de contenido (imagen, vídeo, carrusel) predominan?  (mira la columna type)
# 3. ¿Cuál es el rango de fechas cubierto por los posts?
# 4. ¿Qué post obtuvo más 'likes' y cuál crees que es la razón?

# %%
df.shape
# Out:
# (200, 58)

# %%
df.columns
# Out:
# Index(['inputUrl', 'id', 'username', 'url', 'fullName', 'biography',
#        'externalUrls', 'followersCount', 'followsCount', 'hasChannel',
#        'highlightReelCount', 'isBusinessAccount', 'joinedRecently',
#        'businessCategoryName', 'private', 'verified', 'profilePicUrl',
#        'profilePicUrlHD', 'igtvVideoCount', 'relatedProfiles',
#        'latestIgtvVideos', 'postsCount', 'fbid', 'type', 'shortCode',
#        'caption', 'hashtags', 'mentions', 'commentsCount', 'firstComment',
#        'latestComments', 'dimensionsHeight', 'dimensionsWidth', 'displayUrl',
#        'images', 'alt', 'likesCount', 'timestamp', 'childPosts',
#        'ownerFullName', 'ownerUsername', 'ownerId', 'isSponsored',
#        'isCommentsDisabled', 'videoUrl', 'videoViewCount', 'videoPlayCount',
#        'productType', 'videoDuration', 'musicInfo.artist_name',
#        'musicInfo.song_name', 'musicInfo.uses_original_audio',
#        'musicInfo.should_mute_audio', 'musicInfo.should_mute_audio_reason',
#        'musicInfo.audio_id', 'taggedUsers', 'coauthorProducers', 'isPinned'],
#       dtype='object')

# %%
df["type"].value_counts ()
# Out:
# type
# Video      83
# Sidecar    67
# Image      50
# Name: count, dtype: int64

# %%
df ["timestamp"] = pd.to_datetime (df ["timestamp"])

# %%
df["timestamp"].max()
# Out:
# Timestamp('2025-05-20 21:00:01+0000', tz='UTC')

# %%
df["timestamp"].min()
# Out:
# Timestamp('2024-03-16 17:00:01+0000', tz='UTC')

# %%
df["likesCount"].sort_values(ascending=False)
# Out:
# 85     558944
# 156    186613
# 109    136515
# 176     84230
# 167     81218
#         ...
# 135       282
# 182       233
# 38        223
# 46        219
# 143       168
# Name: likesCount, Length: 200, dtype: int64

# %%
df["likesCount"].max()
# Out:
# 558944

# %%
df[df["likesCount"]==df["likesCount"].max()]
# Out:
#                                 inputUrl                   id   username  \
# 85  https://www.instagram.com/disneylat/  3506371026641991220  disneylat
#
#                                          url fullName  \
# 85  https://www.instagram.com/p/DCpId8Ft7Y0/   Disney
#
#                                           biography externalUrls  \
# 85  La cuenta oficial de Disney para Latinoamérica.           []
#
#     followersCount  followsCount  hasChannel  ...  videoDuration  \
# 85          569613            36       False  ...         43.066
#
#     musicInfo.artist_name  musicInfo.song_name  musicInfo.uses_original_audio  \
# 85              disneylat       Original audio                           True
#
#     musicInfo.should_mute_audio  musicInfo.should_mute_audio_reason  \
# 85                        False                                 NaN
#
#    musicInfo.audio_id taggedUsers  coauthorProducers isPinned
# 85       1.920758e+15         NaN                NaN      NaN
#
# [1 rows x 58 columns]

# %% [markdown]
# ## 🧹 Sección 2 (Limpieza)
#
# Explica por qué es importante limpiar y normalizar el texto de los captions.
# Entregue un grafico de barras con las frecuencia en los captions

# %% [markdown]
# Limpiar y normalizar el texto de los captions es fundamental porque permite eliminar todo el “ruido” que viene en los contenidos de redes sociales —como emojis, hashtags, URLs, menciones, mayúsculas mezcladas o palabras repetidas con variaciones—, y unificar la forma en que se escribe cada término. Esto asegura que el análisis sea más preciso y coherente, ya que evita contar palabras como si fueran diferentes cuando significan lo mismo, reduce distorsiones en las métricas y facilita identificar patrones reales, tendencias y temas relevantes dentro del contenido.

# %%
import re, nltk, string
nltk.download('stopwords')
from nltk.corpus import stopwords

def clean_caption(text):
    text = text.lower()
    text = re.sub(r"http\S+", " ", text)        # URLs
    text = re.sub(r"@[\w_]+", " ", text)        # Menciones
    text = re.sub(r"[#]", " ", text)             # Hashtags (opcional: conservar)
    text = re.sub(r"[{}]".format(string.punctuation), " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df['caption_clean'] = df['caption'].fillna("").apply(clean_caption)
df[['caption', 'caption_clean']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                              caption  \
# 0  En cada imagen se esconde un Mickey, ¿puedes e...
# 1                         Esto se va a descontrolar.
# 2  Los 2000 hechos canción. \n\nVuelve a ver #Liz...
# 3  Con ser ella misma alcanzaba 🥹\n\n#Mulán dispo...
# 4  Llevábamos años esperando este momento, y no d...
#
#                                        caption_clean
# 0  en cada imagen se esconde un mickey ¿puedes en...
# 1                          esto se va a descontrolar
# 2  los 2000 hechos canción vuelve a ver lizziemcg...
# 3  con ser ella misma alcanzaba 🥹 mulán disponibl...
# 4  llevábamos años esperando este momento y no de...

# %%
from collections import Counter
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter
import nltk
nltk.download('stopwords')
stopwords=set(stopwords.words('spanish'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def limpiar_texto(texto):
    texto = texto.lower()
    texto = re.sub(r'[^a-záéíóúüñ ]', '', texto)
    palabras = [palabra for palabra in texto.split() if palabra not in stopwords] # Corrected 'stop_words' to 'stopwords'
    return " ".join(palabras)

# %%
df['clean_text'] = df['caption_clean'].apply(limpiar_texto)

# %%
todas_palabras = " ".join(df["clean_text"]).split()
frecuencias = Counter(todas_palabras)

# Convertimos a DataFrame para visualizar
freq_df = pd.DataFrame(frecuencias.items(), columns=["palabra", "frecuencia"])
freq_df = freq_df.sort_values(by="frecuencia", ascending=False).head(20)

# %%
plt.figure(figsize=(10, 6))
plt.bar(freq_df["palabra"], freq_df["frecuencia"])
plt.xticks(rotation=45)
plt.title("Palabras más frecuentes en captions")
plt.xlabel("Palabras")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## 🗂 Sección 3 (Temas)
# 5. Pida a chatgpt o a una IA que le de 3 temas para clasificar un caption y denle un ejemplo.
# 6. Escriba un prompt en donde le pida clasificar un caption y que de respuesta solo regrese una palabra.
# 7. Apliquelo en toda la columna caption creando una columna topics.
#
# 10. Lista los nombres de los temas generados. ¿Alguno es inesperado?
# 11. Con un heatmap *tipo de contenido × tema*, indica qué tema es “propiedad” de cada formato.
# 12. Para el tema dominante, proporciona dos insights accionables.

# %%
df.head()
# Out:
#                                inputUrl                   id   username  \
# 0  https://www.instagram.com/disneylat/  3626608212947059675  disneylat
# 1  https://www.instagram.com/disneylat/  3636752063146304692  disneylat
# 2  https://www.instagram.com/disneylat/  3629059382491345626  disneylat
# 3  https://www.instagram.com/disneylat/  3624961017727223603  disneylat
# 4  https://www.instagram.com/disneylat/  3634637246638652679  disneylat
#
#                                         url fullName  \
# 0  https://www.instagram.com/p/DJUTPSAOUPb/   Disney
# 1  https://www.instagram.com/p/DJ4VrusASS0/   Disney
# 2  https://www.instagram.com/p/DJdAkfiMfLa/   Disney
# 3  https://www.instagram.com/p/DJOctb6RQcz/   Disney
# 4  https://www.instagram.com/p/DJw01GVTP0H/   Disney
#
#                                          biography externalUrls  \
# 0  La cuenta oficial de Disney para Latinoamérica.           []
# 1  La cuenta oficial de Disney para Latinoamérica.           []
# 2  La cuenta oficial de Disney para Latinoamérica.           []
# 3  La cuenta oficial de Disney para Latinoamérica.           []
# 4  La cuenta oficial de Disney para Latinoamérica.           []
#
#    followersCount  followsCount  hasChannel  ...  musicInfo.song_name  \
# 0          569613            36       False  ...                  NaN
# 1          569613            36       False  ...                  NaN
# 2          569613            36       False  ...       Original audio
# 3          569613            36       False  ...                  NaN
# 4          569613            36       False  ...                  NaN
#
#    musicInfo.uses_original_audio  musicInfo.should_mute_audio  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                           True                        False
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    musicInfo.should_mute_audio_reason  musicInfo.audio_id  taggedUsers  \
# 0                                 NaN                 NaN          NaN
# 1                                 NaN                 NaN          NaN
# 2                                 NaN        6.053466e+14          NaN
# 3                                 NaN                 NaN          NaN
# 4                                 NaN                 NaN          NaN
#
#   coauthorProducers isPinned  \
# 0               NaN      NaN
# 1               NaN      NaN
# 2               NaN      NaN
# 3               NaN      NaN
# 4               NaN      NaN
#
#                                        caption_clean  \
# 0  en cada imagen se esconde un mickey ¿puedes en...
# 1                          esto se va a descontrolar
# 2  los 2000 hechos canción vuelve a ver lizziemcg...
# 3  con ser ella misma alcanzaba 🥹 mulán disponibl...
# 4  llevábamos años esperando este momento y no de...
#
#                                           clean_text
# 0  cada imagen esconde mickey puedes encontrarlos...
# 1                                    va descontrolar
# 2  hechos canción vuelve ver lizziemcguire estrel...
# 3          ser misma alcanzaba mulán disponible solo
# 4  llevábamos años esperando momento decepcionó v...
#
# [5 rows x 60 columns]

# %%
import requests
import json

# %%
import os
os.environ["OPENAI_API_KEY"] =



from openai import OpenAI

client = OpenAI()

# %%
from openai import OpenAI

client = OpenAI()

# %%
def suma(a,b):
 return a+b

# %%
suma(5,10)
# Out:
# 15

# %%
def call_llm(prompt):
  response = client.responses.create(
  model="gpt-4o-mini",
  input=prompt
)
  return response.output_text

# %%
call_llm("Dame tres temas para clasificar un caption")
# Out:
# 'Claro, aquí tienes tres temas para clasificar un caption:\n\n1. **Inspiración Personal**: Mensajes motivacionales y reflexiones sobre el crecimiento personal.\n  \n2. **Aventuras y Viajes**: Experiencias de viaje, exploración de nuevos lugares y culturas.\n\n3. **Comida y Gastronomía**: Descripciones de platos, recetas y experiencias culinarias.\n\n¿Te gustaría ejemplos para alguno de estos temas?'

# %%
def classify_topics(text):
  prompt = (f"Clasifica por tematicas el siguiente caption:{text} "
              f"solo tienes entre estos Inspiración_Personal, Experiencias_de_viaje, Comida_Gastronomía. solo responde con una palabra")
  try:
    respuesta = call_llm(prompt)
  except:
    respuesta = "deafult"
  return respuesta

# %%
sample = df.sample(10, replace = True ,random_state=42)
sample['topic'] = sample['caption_clean'].apply(classify_topics)

# %%
sample['topic'].value_counts()
# Out:
# topic
# Inspiración_Personal     6
# Experiencias_de_viaje    3
# Comida_Gastronomía       1
# Name: count, dtype: int64

# %%
pd.crosstab(sample['topic'], sample['type'])
# Out:
# type                   Image  Sidecar  Video
# topic
# Comida_Gastronomía         0        1      0
# Experiencias_de_viaje      1        1      1
# Inspiración_Personal       1        1      4

# %%
import seaborn as sns
sns.heatmap(pd.crosstab(sample['topic'], sample['type']))
# Out:
# <Axes: xlabel='type', ylabel='topic'>

# %% [markdown]
# ## 📝 Sección 4 (Micro‑campaña)
#
# Cree una columna para una publicidad especifica:

# %%
import pandas as pd

# Lista de diccionarios con la información
datos = [
    {"Nombre": "Ana Torres", "Personaje de Interés": "Estudiante universitaria", "Rango de Edad": "18-24", "Producto a Vender": "Laptop económica"},
    {"Nombre": "Carlos Pérez", "Personaje de Interés": "Emprendedor digital", "Rango de Edad": "25-34", "Producto a Vender": "Software de productividad"},
    {"Nombre": "Lucía Gómez", "Personaje de Interés": "Madre primeriza", "Rango de Edad": "25-34", "Producto a Vender": "Pañales ecológicos"},
    {"Nombre": "Marco Díaz", "Personaje de Interés": "Gamer profesional", "Rango de Edad": "18-24", "Producto a Vender": "Silla ergonómica para gaming"},
    {"Nombre": "Teresa Ríos", "Personaje de Interés": "Ejecutiva de marketing", "Rango de Edad": "35-44", "Producto a Vender": "Cursos de liderazgo online"},
    {"Nombre": "Andrés López", "Personaje de Interés": "Jubilado activo", "Rango de Edad": "65-74", "Producto a Vender": "Viajes culturales guiados"},
    {"Nombre": "Valentina Cruz", "Personaje de Interés": "Influencer de moda", "Rango de Edad": "18-24", "Producto a Vender": "Ropa de diseñador"},
    {"Nombre": "Roberto Silva", "Personaje de Interés": "Dueño de cafetería", "Rango de Edad": "35-44", "Producto a Vender": "Cafetera industrial"},
    {"Nombre": "Elena Fuentes", "Personaje de Interés": "Freelance creativa", "Rango de Edad": "25-34", "Producto a Vender": "Tableta gráfica"},
    {"Nombre": "Javier Ramírez", "Personaje de Interés": "Papá de familia numerosa", "Rango de Edad": "35-44", "Producto a Vender": "Plan de supermercado online"}
]

# Crear el DataFrame
df = pd.DataFrame(datos)

# %%
df
# Out:
#            Nombre      Personaje de Interés Rango de Edad  \
# 0      Ana Torres  Estudiante universitaria         18-24
# 1    Carlos Pérez       Emprendedor digital         25-34
# 2     Lucía Gómez           Madre primeriza         25-34
# 3      Marco Díaz         Gamer profesional         18-24
# 4     Teresa Ríos    Ejecutiva de marketing         35-44
# 5    Andrés López           Jubilado activo         65-74
# 6  Valentina Cruz        Influencer de moda         18-24
# 7   Roberto Silva        Dueño de cafetería         35-44
# 8   Elena Fuentes        Freelance creativa         25-34
# 9  Javier Ramírez  Papá de familia numerosa         35-44
#
#               Producto a Vender
# 0              Laptop económica
# 1     Software de productividad
# 2            Pañales ecológicos
# 3  Silla ergonómica para gaming
# 4    Cursos de liderazgo online
# 5     Viajes culturales guiados
# 6             Ropa de diseñador
# 7           Cafetera industrial
# 8               Tableta gráfica
# 9   Plan de supermercado online

# %%
def generar_caption(nombre, topic, personaje, publico):
    prompt = (
        f"Actúa como un experto community manager. Escribe un caption persuasivo, claro y emocional "
        f"de máximo 220 caracteres. Dirígete a {nombre}. "
        f"El tema del contenido es '{topic}'. "
        f"El personaje es {personaje} y el público objetivo tiene {publico} años. "
        f"Tu misión es motivar la compra. "
        f"No incluyas hashtags, emojis ni menciones."
    )

    response = call_llm(prompt)
    return response

# %%
df["Caption_Publicitario"] = df.apply(
    lambda row: generar_caption(
        nombre=row["Nombre"],
        topic=row["Producto a Vender"],
        personaje=row["Personaje de Interés"],
        publico=row["Rango de Edad"]
    ),
    axis=1
)

# %%
df.head()
# Out:
#          Nombre      Personaje de Interés Rango de Edad  \
# 0    Ana Torres  Estudiante universitaria         18-24
# 1  Carlos Pérez       Emprendedor digital         25-34
# 2   Lucía Gómez           Madre primeriza         25-34
# 3    Marco Díaz         Gamer profesional         18-24
# 4   Teresa Ríos    Ejecutiva de marketing         35-44
#
#               Producto a Vender  \
# 0              Laptop económica
# 1     Software de productividad
# 2            Pañales ecológicos
# 3  Silla ergonómica para gaming
# 4    Cursos de liderazgo online
#
#                                 Caption_Publicitario
# 0  Ana Torres, tu camino hacia el éxito académico...
# 1  Carlos Pérez, imagina optimizar cada minuto de...
# 2  Lucía, cada pequeño gesto cuenta. Con los paña...
# 3  Marco, maximiza tu rendimiento en cada partida...
# 4  Teresa Ríos, es hora de potenciar tu carrera. ...
